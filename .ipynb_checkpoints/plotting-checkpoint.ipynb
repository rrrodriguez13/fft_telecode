# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
# %matplotlib widget

# %%
# sorts data files in folder
path = 'output' # num folder
files = sorted(glob.glob(os.path.join(path, "*.npz")), key=lambda x: int(x.split("_")[-1].split(".")[0]))
print(len(files))
# Out:
# 114

# %%
# loads and shapes data
data = np.concatenate([np.load(d)['data'] for d in files], axis=0).view('int8')
data_shape = data.shape
print('Data shape is', data_shape)
# Out:
# Data shape is (14592, 2048, 2)

# %%
# plots data
plt.figure(figsize=(8,4))
data_comp = data[...,0] + 1j * data[...,1] # computes the complex data
plt.plot(np.angle(data_comp[:-1,-1] * data_comp[1:,0].conj()))
plt.plot(np.angle(data_comp[:,-2] * data_comp[:,-1].conj()))
print(data.shape)
#plt.xlim(1500,2050)
plt.show()

# for checking specific number of files
#for i in range(1):
#    data = np.load(data_files[i])['data'].view('int8')
#    print(data.shape)
#    plt.plot(data[:,0])
#plt.close('all')
# Out:
# (14592, 2048, 2)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from scipy.fft import fft, fftshift
from matplotlib.ticker import ScalarFormatter

num_samples = 2048
sampling_rate = 2.2e6

freqs = np.fft.fftshift(np.fft.fftfreq(num_samples, 1/sampling_rate))

# power spectra (absolute value squared)
def perform_power(data):
    return np.abs(data)**2

# shifts it!
def shift(data):
    return fftshift(data)

# complex stuff
d1 = data - np.mean(data)
d = d1[...,0] + 1j * d1[...,1]

# shifting the mean
pwr_shift = shift(np.mean(perform_power(fft(data)), axis=0))


# plotting
plt.figure(figsize=(10, 4))
plt.title('Plotting the Data')
plt.semilogy(freqs, pwr_shift, linewidth=0.8, label='data')
plt.xlabel('Frequency [MHz]', fontsize=16)
plt.ylabel('Power [arbitrary]', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.gca().ticklabel_format(axis='x', style='plain')
plt.tight_layout()
plt.legend()

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# shifting d instead of data
pwr_shift2 = shift(np.mean(perform_power(fft(d)), axis=0))

# plotting
plt.figure(figsize=(10, 4))
plt.title('Plotting the Data')
plt.semilogy(freqs, pwr_shift2, linewidth=0.8, label='data')
plt.xlabel('Frequency [MHz]', fontsize=16)
plt.ylabel('Power [arbitrary]', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.gca().ticklabel_format(axis='x', style='plain')
plt.tight_layout()
plt.legend()

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')
